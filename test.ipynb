# %%
import pandas as pd
df = pd.read_csv("Data.csv")
df.describe()
# Out:
#        0) AngryMan_v4_bf_100__be_1__bs_0  1) AngryMan_v4_bf_100__be_2__bs_0  \
# count                          27.000000                          27.000000
# mean                        81525.185185                       78801.111111
# std                         21280.703406                       22508.591280
# min                         43300.000000                       38145.000000
# 25%                         68987.500000                       63525.000000
# 50%                         80595.000000                       82185.000000
# 75%                         88927.500000                       94132.500000
# max                        140525.000000                      128940.000000
#
#        2) TitForTat__first_move_1__forgiveness_0  \
# count                                  27.000000
# mean                               111636.296296
# std                                 14326.973793
# min                                 89990.000000
# ...
